# %% [markdown]
# # Formatting the municipalities' shapefiles

# %% [markdown]
# Procedure:
#  - One year after the other, if data is in state files, they are first concatenated together.
#  - Then, the columns are inspected and renamed.
#  - The municipalities' code is corrected to exclude the last digit if code is 7 digitis long.
#
#
# UPDATE (18/08/2023): Included the formatting of the years 1980 and 1991.

# %%
import geopandas as gpd
import pandas as pd
import locale

import sys
sys.path.append('../utils/')
from cerrado_states_codes import cerrado_state_code

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# User inputs
# Directory with year folders
in_dir = '../../data/BR_municipios/'

# Output directory
out_file = '../data/municipalities_shp/municipalities_{}.shp'

# Character encoding
encode = locale.getpreferredencoding()

# %%
# Function that, given a year folder, gets the list of all shapefiles inside the folder, reads them, and concatenates
# them.
def readSHP(year, input_dir):
    # Read list of files in directory
    list_fp = fileList.fileList(input_dir + str(year), in_extensions = 'shp')
    
    # Read files iteratively and save into list
    list_gdf = []
    for file in list_fp:
        gdf = gpd.read_file(file, encoding = encode)
        
        # If CRS is None, we set the CRS to Brazilian Geodetic System (currently SIRGAS 2000) with Geographic projection.
        if gdf.crs == None:
            gdf.crs = 'epsg:4674'
        
        list_gdf.append(gdf)
    
    # Converting list fo GeoDataFrames to GeoDataFrame
    list_gdf = gpd.GeoDataFrame(pd.concat(list_gdf, ignore_index = True))

    return list_gdf

# %%
# Function that adds the state character and numerical codes
def addStateCodes(data, select = False):
    
    # First, get the numerical state code from the municipalities' code
    data['s_code'] = data['m_code'].apply(lambda x: int(str(x)[:2]))
    
    # Read the state's character-numerical dictionary
    s_codes = cerrado_state_code()
    
    # If select option, select only those states in s_codes
    if select == True:
        # First, get list of the states
        states = list(cerrado_state_code().keys())

        # Then, select only those municipalities in these states
        data = data[data['s_code'].isin(states)]

    
    # Now, get the alphabetical code fomr the numerical one
    data['state'] = data['s_code'].apply(lambda x: s_codes[x])
    
    return data

# %%
# Function that corrects the municipality code by deleting the 7th digit, if present
def correct_m_code(data):
    data['m_code'] = data['m_code'].apply(lambda x: int(str(x)[:6]))
    
    return data

# %%
# Function that puts the columns in order
def order_columns(data):
    data = data[['year', 'state', 's_code', 'm_code', 'm_name', 'area_km2', 'latitude', 'longitude', 'geometry']]
    
    return data

# %%
# Function that calcualtes the area of a polygon in km2
def calculate_area(data):
    
    # Store original crs
    crs = data.crs
    # Transform to a CRS with m units (for Brazil, Brazil SIRGAS 2000 polyconic)
    data = data.to_crs('epsg:5880')
    
    # Then, calculate the area in m2
    data['area_m2'] = data['geometry'].area
    
    # Transform to km2
    data['area_km2'] = data['area_m2']*1e-06
    
#     print(data)
    
    # Drop m2 column
    data = data.drop(columns = ['area_m2'])
    
    # Return to original crs
    data = data.to_crs(crs)
    
    return data

# %%
# Function that selects only those states that we are interested in
def select_states(data):
    # First, get list of the states
    states = list(tools.cerrado_state_code().values())
    
    # Then, select only those municipalities in these states
    data = data[data['state'].isin(states)]
    
    return data

# %%
# Function that aggregates duplicated municipalities into a single MultiPolygon
def aggregate_municipalities(data):
    # First, just checking for information if there are repeated municipalities
    if len(data[data['m_code'].duplicated()]['m_code'].unique()) != 0:
        print('There were duplicated municipalities.')
        
        # Aggregate them into MultiPolygons
        data = data.dissolve(by = 'm_code').reset_index()
        
    return data

# %%
# Function that returns the latitude and longitude of the centroid of each municipality
def get_latlon(data):
    # Store original CRS
    crs = data.crs
    
    # Transform to projected CRS
    data = data.to_crs('epsg:5880')
    
    # Get latitude and longitude from the centroid
    data['latitude'] = data.centroid.y
    data['longitude'] = data.centroid.y
    
    # Return to original CRS
    data = data.to_crs(crs)
    
    return data

# %% [markdown]
# ## Year 2000

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2000 = readSHP(2000, in_dir)
gdf_2000.head(2)
# Out:
#    MSLINK   CODIGO     AREA_1  PERIMETRO_ GEOCODIGO           NOME SEDE  \
# 0      17  1100205  34082.366    1996.549   1100205    Porto Velho    T
# 1      10  1100106  24855.652     960.222   1100106  Guajar -Mirim    T
#
#    LATITUDESE  LONGITUDES  AREA_TOT_G RESERVADO  \
# 0      -8.762     -63.904   34082.366         F
# 1     -10.783     -65.339   24855.652         F
#
#                                             geometry
# 0  POLYGON ((-66.77773 -9.76616, -66.78159 -9.758...
# 1  POLYGON ((-65.40175 -10.59234, -65.39728 -10.5...

# %%
# Select relevant columns
gdf_2000 = gdf_2000[['CODIGO', 'AREA_1', 'NOME', 'LATITUDESE', 'LONGITUDES', 'geometry']]

# %%
# Rename the relevant columns
gdf_2000 = gdf_2000.rename(columns = {'CODIGO':'m_code', 'AREA_1':'area_km2', 'NOME':'m_name', 'LATITUDESE':'latitude', 'LONGITUDES':'longitude'})

# %%
# Add state codes
gdf_2000 = addStateCodes(gdf_2000)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2000 = aggregate_municipalities(gdf_2000)
# Out:
# There were duplicated municiaplities.

# %%
# Correct municipality code
gdf_2000 = correct_m_code(gdf_2000)

# %%
# Adding year column
gdf_2000['year'] = 2000

# %%
# Ordering the columns
gdf_2000 = order_columns(gdf_2000)

# %%
# Checking the GeoDataFrame again
gdf_2000
# Out:
#       year state  s_code  m_code                 m_name    area_km2  latitude  \
# 0     2000    RO      11  110001  Alta Floresta D'Oeste  7066.70200   -11.929
# 1     2000    RO      11  110002              Ariquemes  4426.55800    -9.913
# 2     2000    RO      11  110003                 Cabixi  1314.35500   -13.492
# 3     2000    RO      11  110004                 Cacoal  3792.63800   -11.438
# 4     2000    RO      11  110005             Cerejeiras  2783.30500   -13.189
# ...    ...   ...     ...     ...                    ...         ...       ...
# 3525  2000    GO      52  522200             Vian¢polis   954.27900   -16.742
# 3526  2000    GO      52  522205         Vicentin¢polis   737.25100   -17.735
# 3527  2000    GO      52  522220               Vila Boa  1060.17000   -15.038
# 3528  2000    GO      52  522230          Vila Prop¡cio  2181.57500   -15.457
# 3529  2000    DF      53  530010               Bras¡lia     0.05726   -15.780
#
#       longitude                                           geometry
# 0       -61.996  POLYGON ((-62.89162 -12.85844, -62.88899 -12.8...
# 1       -63.041  POLYGON ((-63.59644 -9.99999, -63.59734 -9.998...
# 2       -60.545  POLYGON ((-60.91846 -13.54792, -60.91881 -13.5...
# 3       -61.448  POLYGON ((-61.79527 -11.39743, -61.79170 -11.3...
# 4       -60.812  POLYGON ((-61.90644 -13.27527, -61.90720 -13.2...
# ...         ...                                                ...
# 3525    -48.516  POLYGON ((-48.59655 -16.92375, -48.59824 -16.9...
# 3526    -49.806  POLYGON ((-50.08652 -17.78481, -50.08527 -17.7...
# 3527    -47.059  POLYGON ((-47.21584 -14.93810, -47.21491 -14.9...
# 3528    -48.889  POLYGON ((-49.09162 -15.48003, -49.09160 -15.4...
# 3529    -47.930  POLYGON ((-48.27837 -15.86806, -48.27980 -15.8...
#
# [3530 rows x 9 columns]

# %%
# Save to file
gdf_2000.to_file(out_file.format(2000))

# %%
del gdf_2000

# %% [markdown]
# ## Year 2001

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2001 = readSHP(2001, in_dir)
gdf_2001.head(2)
# Out:
#    MSLINK  MAPID   CODIGO    AREA_1  PERIMETRO_ GEOCODIGO  \
# 0       1     99  1100015  7066.702     608.314   1100015
# 1       2     99  1100023  4426.558     427.640   1100023
#
#                     NOME SEDE  LATITUDESE  LONGITUDES  AREA_TOT_G  \
# 0  Alta Floresta d'Oeste    T     -11.929     -61.996    7066.702
# 1              Ariquemes    T      -9.913     -63.041    4426.558
#
#                                             geometry
# 0  POLYGON ((-62.89212 -12.85885, -62.88114 -12.8...
# 1  POLYGON ((-63.59694 -10.00039, -63.60485 -9.98...

# %%
# Select relevant columns
gdf_2001 = gdf_2001[['CODIGO', 'AREA_1', 'NOME', 'LATITUDESE', 'LONGITUDES', 'geometry']]

# %%
# Rename the relevant columns
gdf_2001 = gdf_2001.rename(columns = {'CODIGO':'m_code', 'AREA_1':'area_km2', 'NOME':'m_name', 'LATITUDESE':'latitude', 'LONGITUDES':'longitude'})

# %%
# Add state codes
gdf_2001 = addStateCodes(gdf_2001)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2001 = aggregate_municipalities(gdf_2001)
# Out:
# There were duplicated municiaplities.

# %%
# Correct municipality code
gdf_2001 = correct_m_code(gdf_2001)

# %%
# Adding year column
gdf_2001['year'] = 2001

# %%
# Ordering the columns
gdf_2001 = order_columns(gdf_2001)

# %%
# Checking the GeoDataFrame again
gdf_2001
# Out:
#       year state  s_code  m_code                 m_name  area_km2  latitude  \
# 0     2001    RO      11  110001  Alta Floresta d'Oeste  7066.702   -11.929
# 1     2001    RO      11  110002              Ariquemes  4426.558    -9.913
# 2     2001    RO      11  110003                 Cabixi  1314.355   -13.492
# 3     2001    RO      11  110004                 Cacoal  3792.638   -11.438
# 4     2001    RO      11  110005             Cerejeiras  2783.305   -13.189
# ...    ...   ...     ...     ...                    ...       ...       ...
# 3545  2001    GO      52  522200             Vianópolis   954.279   -16.742
# 3546  2001    GO      52  522205         Vicentinópolis   737.251   -17.735
# 3547  2001    GO      52  522220               Vila Boa  1060.170   -15.038
# 3548  2001    GO      52  522230          Vila Propício  2181.575   -15.457
# 3549  2001    DF      53  530010               Brasília  5801.937   -15.780
#
#       longitude                                           geometry
# 0       -61.996  POLYGON ((-62.89212 -12.85885, -62.88114 -12.8...
# 1       -63.041  POLYGON ((-63.59694 -10.00039, -63.60485 -9.98...
# 2       -60.545  POLYGON ((-60.91892 -13.54834, -60.91861 -13.5...
# 3       -61.448  POLYGON ((-61.79589 -11.39774, -61.78298 -11.4...
# 4       -60.812  POLYGON ((-61.50094 -13.00434, -61.47948 -13.0...
# ...         ...                                                ...
# 3545    -48.516  POLYGON ((-48.59694 -16.92420, -48.59864 -16.9...
# 3546    -49.806  POLYGON ((-50.08692 -17.78526, -50.08365 -17.7...
# 3547    -47.059  POLYGON ((-47.11127 -14.67229, -47.11645 -14.6...
# 3548    -48.889  POLYGON ((-49.08259 -15.51287, -49.08138 -15.4...
# 3549    -47.930  POLYGON ((-48.28282 -15.82953, -48.26787 -15.8...
#
# [3550 rows x 9 columns]

# %%
# Save to file
gdf_2001.to_file(out_file.format(2001))

# %%
del gdf_2001

# %% [markdown]
# ## Year 2005

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2005 = readSHP(2005, in_dir)
gdf_2005.head(2)
# Out:
#    GEOCODIGO              NOME  UF  ID_UF REGIAO           MESOREGIAO  \
# 0    1200336       Mâncio Lima  AC     12  Norte        VALE DO JURUA
# 1    1300201  Atalaia do Norte  AM     13  Norte  SUDOESTE AMAZONENSE
#
#         MICROREGIA LATITUDE LONGITUDE SEDE  \
# 0  CRUZEIRO DO SUL   -7.614   -72.896    t
# 1    ALTO SOLIMOES   -4.372   -70.192    t
#
#                                             geometry
# 0  POLYGON ((-73.80098 -7.11146, -73.73762 -7.134...
# 1  POLYGON ((-73.80098 -7.11146, -73.79617 -7.102...

# %%
# Get the relevant columns and rename
gdf_2005 = gdf_2005[['GEOCODIGO', 'NOME', 'UF', 'ID_UF', 'LATITUDE', 'LONGITUDE', 'geometry']]
# Rename these columns
gdf_2005 = gdf_2005.rename(columns = {'GEOCODIGO':'m_code', 'NOME':'m_name', 'UF':'state', 
                                      'ID_UF':'s_code', 'LATITUDE':'latitude', 'LONGITUDE':'longitude'})
# Add year column
gdf_2005['year'] = 2005

# %%
# Select only those states that we are intereseted in 
gdf_2005 = select_states(gdf_2005)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2005 = aggregate_municipalities(gdf_2005)
# Out:
# There were duplicated municiaplities.

# %%
# Calculate area of each municipality
gdf_2005 = calculate_area(gdf_2005)

# %%
# Place columns in the right order
gdf_2005 = order_columns(gdf_2005)

# %%
# Correct municipality code
gdf_2005 = correct_m_code(gdf_2005)

# %%
# Checking the GeoDataFrame again
gdf_2005
# Out:
#       year state  s_code  m_code                 m_name     area_km2 latitude  \
# 0     2005    RO      11  110001  Alta Floresta D'Oeste  7137.928186  -11.929
# 1     2005    RO      11  110002              Ariquemes  4480.100575   -9.913
# 2     2005    RO      11  110003                 Cabixi  1322.454806  -13.492
# 3     2005    RO      11  110004                 Cacoal  3821.386881  -11.438
# 4     2005    RO      11  110005             Cerejeiras  2804.983150  -13.189
# ...    ...   ...     ...     ...                    ...          ...      ...
# 3549  2005    GO      52  522200             Vianópolis   957.618875  -16.742
# 3550  2005    GO      52  522205         Vicentinópolis   739.898831  -17.735
# 3551  2005    GO      52  522220               Vila Boa  1068.373432  -15.038
# 3552  2005    GO      52  522230          Vila Propício  2188.854372  -15.457
# 3553  2005    DF      53  530010               Brasília  5834.492333   -15.78
#
#      longitude                                           geometry
# 0      -61.996  POLYGON ((-62.89162 -12.85844, -62.88065 -12.8...
# 1      -63.041  POLYGON ((-63.10106 -9.75217, -63.03356 -9.751...
# 2      -60.545  POLYGON ((-60.91846 -13.54792, -60.91814 -13.5...
# 3      -61.448  POLYGON ((-61.79527 -11.39743, -61.78251 -11.4...
# 4      -60.812  POLYGON ((-61.50047 -13.00392, -61.47901 -13.0...
# ...        ...                                                ...
# 3549   -48.516  POLYGON ((-48.25938 -16.73830, -48.26485 -16.7...
# 3550   -49.806  POLYGON ((-50.08652 -17.78481, -50.08324 -17.7...
# 3551   -47.059  POLYGON ((-47.10880 -14.67637, -47.10180 -14.6...
# 3552   -48.889  POLYGON ((-48.90783 -15.16350, -48.90097 -15.1...
# 3553    -47.93  POLYGON ((-48.28216 -15.82915, -48.26746 -15.8...
#
# [3554 rows x 9 columns]

# %%
# Save to file
gdf_2005.to_file(out_file.format(2005))

# %%
del gdf_2005

# %% [markdown]
# ## Year 2007

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2007 = readSHP(2007, in_dir)
gdf_2007.head(2)
# Out:
#    GEOCODIG_M  UF SIGLA             NOME_MUNIC REGIão MESORREGIã  \
# 0     1100015  11    RO  Alta Floresta D'Oeste  Norte       1102
# 1     1100023  11    RO              Ariquemes  Norte       1102
#
#            NOME_MESO MICRORREGI NOME_MICRO  \
# 0  Leste Rondoniense      11006     Cacoal
# 1  Leste Rondoniense      11003  Ariquemes
#
#                                             geometry
# 0  POLYGON ((-62.18255 -11.86729, -62.16276 -11.8...
# 1  POLYGON ((-62.53640 -9.73224, -62.50826 -9.754...

# %%
# Get the relevant columns and rename
gdf_2007 = gdf_2007[['GEOCODIG_M', 'NOME_MUNIC', 'UF', 'SIGLA', 'geometry']]
# Rename these columns
gdf_2007 = gdf_2007.rename(columns = {'GEOCODIG_M':'m_code', 'NOME_MUNIC':'m_name', 'SIGLA':'state', 
                                      'UF':'s_code'})
# Add year column
gdf_2007['year'] = 2007

# %%
# Select only those states that we are intereseted in 
gdf_2007 = select_states(gdf_2007)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2007 = aggregate_municipalities(gdf_2007)

# %%
# Calculate area of each municipality
gdf_2007 = calculate_area(gdf_2007)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2007 = get_latlon(gdf_2007)

# %%
# Place columns in the right order
gdf_2007 = order_columns(gdf_2007)

# %%
# Correct municipality code
gdf_2007 = correct_m_code(gdf_2007)

# %%
# Checking the GeoDataFrame again
gdf_2007
# Out:
#       year state s_code  m_code                 m_name     area_km2  \
# 0     2007    RO     11  110001  Alta Floresta D'Oeste  7137.513828
# 1     2007    RO     11  110002              Ariquemes  4481.039426
# 2     2007    RO     11  110003                 Cabixi  1322.469647
# 3     2007    RO     11  110004                 Cacoal  3821.868382
# 4     2007    RO     11  110005             Cerejeiras  2805.536318
# ...    ...   ...    ...     ...                    ...          ...
# 5561  2007    GO     52  522200             Vianópolis   957.669648
# 5562  2007    GO     52  522205         Vicentinópolis   740.278806
# 5563  2007    GO     52  522220               Vila Boa  1068.947033
# 5564  2007    GO     52  522230          Vila Propício  2188.902882
# 5565  2007    DF     53  530010               Brasília  5833.663529
#
#           latitude     longitude  \
# 0     8.606929e+06  8.606929e+06
# 1     8.886181e+06  8.886181e+06
# 2     8.500044e+06  8.500044e+06
# 3     8.740191e+06  8.740191e+06
# 4     8.528352e+06  8.528352e+06
# ...            ...           ...
# 5561  8.132085e+06  8.132085e+06
# 5562  8.034672e+06  8.034672e+06
# 5563  8.330055e+06  8.330055e+06
# 5564  8.304588e+06  8.304588e+06
# 5565  8.244786e+06  8.244786e+06
#
#                                                geometry
# 0     POLYGON ((-62.18255 -11.86729, -62.16276 -11.8...
# 1     POLYGON ((-62.53640 -9.73224, -62.50826 -9.754...
# 2     POLYGON ((-60.39986 -13.45628, -60.40241 -13.4...
# 3     POLYGON ((-61.00096 -11.39839, -61.01840 -11.4...
# 4     POLYGON ((-61.50093 -13.00436, -61.47947 -13.0...
# ...                                                 ...
# 5561  POLYGON ((-48.43166 -16.62800, -48.42568 -16.6...
# 5562  POLYGON ((-49.85046 -17.57727, -49.84352 -17.5...
# 5563  POLYGON ((-47.11058 -14.67196, -47.11647 -14.6...
# 5564  POLYGON ((-48.75165 -14.90505, -48.75237 -14.9...
# 5565  POLYGON ((-47.41436 -15.54819, -47.41220 -15.5...
#
# [3554 rows x 9 columns]

# %%
# Save to file
gdf_2007.to_file(out_file.format(2007))

# %%
del gdf_2007

# %% [markdown]
# ## Year 2010

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2010 = readSHP(2010, in_dir)
gdf_2010.head(2)
# Out:
#    ID CD_GEOCODM             NM_MUNICIP  \
# 0   1    1100015  ALTA FLORESTA D'OESTE
# 1   2    1100023              ARIQUEMES
#
#                                             geometry
# 0  POLYGON ((-62.24620 -11.90149, -62.24398 -11.9...
# 1  POLYGON ((-63.13712 -9.78413, -63.09013 -9.782...

# %%
# Select relevant columns
gdf_2010 = gdf_2010[['CD_GEOCODM', 'NM_MUNICIP', 'geometry']]

# %%
# Rename the relevant columns
gdf_2010 = gdf_2010.rename(columns = {'CD_GEOCODM':'m_code', 'NM_MUNICIP':'m_name'})

# %%
# Add state codes
gdf_2010 = addStateCodes(gdf_2010)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2010 = aggregate_municipalities(gdf_2010)

# %%
# Calculate area of each municipality
gdf_2010 = calculate_area(gdf_2010)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2010 = get_latlon(gdf_2010)

# %%
# Correct municipality code
gdf_2010 = correct_m_code(gdf_2010)

# %%
# Adding year column
gdf_2010['year'] = 2010

# %%
# Ordering the columns
gdf_2010 = order_columns(gdf_2010)

# %%
# Checking the GeoDataFrame again
gdf_2010
# Out:
#       year state  s_code  m_code                 m_name     area_km2  \
# 0     2010    RO      11  110001  ALTA FLORESTA D'OESTE  7137.806334
# 1     2010    RO      11  110002              ARIQUEMES  4479.446407
# 2     2010    RO      11  110003                 CABIXI  1322.759675
# 3     2010    RO      11  110004                 CACOAL  3822.843319
# 4     2010    RO      11  110005             CEREJEIRAS  2804.665257
# ...    ...   ...     ...     ...                    ...          ...
# 3550  2010    GO      52  522200             VIANÓPOLIS   958.424277
# 3551  2010    GO      52  522205         VICENTINÓPOLIS   739.003170
# 3552  2010    GO      52  522220               VILA BOA  1067.467465
# 3553  2010    GO      52  522230          VILA PROPÍCIO  2189.954331
# 3554  2010    DF      53  530010               BRASÍLIA  5811.612042
#
#           latitude     longitude  \
# 0     8.606916e+06  8.606916e+06
# 1     8.886192e+06  8.886192e+06
# 2     8.500043e+06  8.500043e+06
# 3     8.740185e+06  8.740185e+06
# 4     8.528364e+06  8.528364e+06
# ...            ...           ...
# 3550  8.132084e+06  8.132084e+06
# 3551  8.034702e+06  8.034702e+06
# 3552  8.330040e+06  8.330040e+06
# 3553  8.304597e+06  8.304597e+06
# 3554  8.244839e+06  8.244839e+06
#
#                                                geometry
# 0     POLYGON ((-62.24620 -11.90149, -62.24398 -11.9...
# 1     POLYGON ((-63.13712 -9.78413, -63.09013 -9.782...
# 2     POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...
# 3     POLYGON ((-61.42679 -11.11376, -61.42900 -10.9...
# 4     POLYGON ((-61.41347 -13.23417, -61.41505 -13.2...
# ...                                                 ...
# 3550  POLYGON ((-48.54164 -16.74126, -48.53875 -16.7...
# 3551  POLYGON ((-49.90713 -17.61460, -49.90588 -17.6...
# 3552  POLYGON ((-46.97635 -14.93112, -46.95851 -14.9...
# 3553  POLYGON ((-48.86700 -15.09735, -48.86644 -15.0...
# 3554  POLYGON ((-48.21763 -15.76267, -48.21755 -15.7...
#
# [3555 rows x 9 columns]

# %%
# Save to file
gdf_2010.to_file(out_file.format(2010))

# %%
del gdf_2010

# %% [markdown]
# ## Year 2013

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2013 = readSHP(2013, in_dir)
gdf_2013.head(2)
# Out:
#               NM_MUNICIP CD_GEOCMU  \
# 0  ALTA FLORESTA D'OESTE   1100015
# 1              ARIQUEMES   1100023
#
#                                             geometry
# 0  POLYGON ((-62.19465 -11.82746, -62.19332 -11.8...
# 1  POLYGON ((-62.53648 -9.73222, -62.52765 -9.736...

# %%
# Select relevant columns
gdf_2013 = gdf_2013[['CD_GEOCMU', 'NM_MUNICIP', 'geometry']]

# %%
# Rename the relevant columns
gdf_2013 = gdf_2013.rename(columns = {'CD_GEOCMU':'m_code', 'NM_MUNICIP':'m_name'})

# %%
# Add state codes
gdf_2013 = addStateCodes(gdf_2013)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2013 = aggregate_municipalities(gdf_2013)

# %%
# Calculate area of each municipality
gdf_2013 = calculate_area(gdf_2013)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2013 = get_latlon(gdf_2013)

# %%
# Correct municipality code
gdf_2013 = correct_m_code(gdf_2013)

# %%
# Adding year column
gdf_2013['year'] = 2013

# %%
# Ordering the columns
gdf_2013 = order_columns(gdf_2013)

# %%
# Checking the GeoDataFrame again
gdf_2013
# Out:
#       year state  s_code  m_code                 m_name     area_km2  \
# 0     2013    RO      11  110001  ALTA FLORESTA D'OESTE  7137.806333
# 1     2013    RO      11  110002              ARIQUEMES  4479.446407
# 2     2013    RO      11  110003                 CABIXI  1322.749453
# 3     2013    RO      11  110004                 CACOAL  3822.982353
# 4     2013    RO      11  110005             CEREJEIRAS  2804.665257
# ...    ...   ...     ...     ...                    ...          ...
# 3552  2013    GO      52  522200            VIANÃ“POLIS   958.424278
# 3553  2013    GO      52  522205        VICENTINÃ“POLIS   739.003170
# 3554  2013    GO      52  522220               VILA BOA  1067.467466
# 3555  2013    GO      52  522230          VILA PROPÃCIO  2189.954331
# 3556  2013    DF      53  530010               BRASÃLIA  5811.611478
#
#           latitude     longitude  \
# 0     8.606916e+06  8.606916e+06
# 1     8.886192e+06  8.886192e+06
# 2     8.500043e+06  8.500043e+06
# 3     8.740186e+06  8.740186e+06
# 4     8.528364e+06  8.528364e+06
# ...            ...           ...
# 3552  8.132084e+06  8.132084e+06
# 3553  8.034702e+06  8.034702e+06
# 3554  8.330040e+06  8.330040e+06
# 3555  8.304597e+06  8.304597e+06
# 3556  8.244839e+06  8.244839e+06
#
#                                                geometry
# 0     POLYGON ((-62.19465 -11.82746, -62.19332 -11.8...
# 1     POLYGON ((-62.53648 -9.73222, -62.52765 -9.736...
# 2     POLYGON ((-60.37075 -13.36363, -60.37134 -13.3...
# 3     POLYGON ((-61.00080 -11.29737, -61.00103 -11.3...
# 4     POLYGON ((-61.49976 -13.00525, -61.49809 -13.0...
# ...                                                 ...
# 3552  POLYGON ((-48.38114 -16.63141, -48.38058 -16.6...
# 3553  POLYGON ((-49.84456 -17.58262, -49.84357 -17.5...
# 3554  POLYGON ((-47.11416 -14.67412, -47.11289 -14.6...
# 3555  POLYGON ((-48.75586 -14.86267, -48.75519 -14.8...
# 3556  POLYGON ((-48.09873 -15.50026, -48.09852 -15.5...
#
# [3557 rows x 9 columns]

# %%
# Save to file
gdf_2013.to_file(out_file.format(2013))

# %%
del gdf_2013

# %% [markdown]
# ## Year 2015

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2015 = readSHP(2015, in_dir)
gdf_2015.head(2)
# Out:
#   NM_MUNICIP CD_GEOCMU                                           geometry
# 0      CAIUÃ   3509106  POLYGON ((-51.86001 -21.58072, -51.85892 -21.5...
# 1   CASTILHO   3511003  POLYGON ((-51.41936 -20.68108, -51.41942 -20.6...

# %%
# Select relevant columns
gdf_2015 = gdf_2015[['CD_GEOCMU', 'NM_MUNICIP', 'geometry']]

# %%
# Rename the relevant columns
gdf_2015 = gdf_2015.rename(columns = {'CD_GEOCMU':'m_code', 'NM_MUNICIP':'m_name'})

# %%
# Add state codes, selecting only the relevant ones
gdf_2015 = addStateCodes(gdf_2015, select = True)
# Out:
# C:\Users\scat8298\.conda\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2015 = aggregate_municipalities(gdf_2015)

# %%
# Calculate area of each municipality
gdf_2015 = calculate_area(gdf_2015)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2015 = get_latlon(gdf_2015)

# %%
# Correct municipality code
gdf_2015 = correct_m_code(gdf_2015)

# %%
# Adding year column
gdf_2015['year'] = 2015

# %%
# Ordering the columns
gdf_2015 = order_columns(gdf_2015)

# %%
# Checking the GeoDataFrame again
gdf_2015
# Out:
#       year state  s_code  m_code                      m_name     area_km2  \
# 0     2015    SP      35  350910                       CAIUÃ   551.451660
# 1     2015    SP      35  351100                    CASTILHO  1066.159482
# 2     2015    SP      35  351440                     DRACENA   488.065194
# 3     2015    SP      35  351530            ESTRELA DO NORTE   265.175088
# 4     2015    SP      35  351535  EUCLIDES DA CUNHA PAULISTA   574.044194
# ...    ...   ...     ...     ...                         ...          ...
# 5567  2015    RO      11  110155              TEIXEIRÃ“POLIS   464.641080
# 5568  2015    RO      11  110160                   THEOBROMA  2220.140924
# 5569  2015    RO      11  110170                       URUPÃ   840.564716
# 5570  2015    RO      11  110175               VALE DO ANARI  3164.553121
# 5571  2015    RO      11  110180             VALE DO PARAÃSO   975.091772
#
#           latitude     longitude  \
# 0     7.586836e+06  7.586836e+06
# 1     7.686360e+06  7.686360e+06
# 2     7.613347e+06  7.613347e+06
# 3     7.510560e+06  7.510560e+06
# 4     7.508048e+06  7.508048e+06
# ...            ...           ...
# 5567  8.777374e+06  8.777374e+06
# 5568  8.868975e+06  8.868975e+06
# 5569  8.759001e+06  8.759001e+06
# 5570  8.913522e+06  8.913522e+06
# 5571  8.840362e+06  8.840362e+06
#
#                                                geometry
# 0     POLYGON ((-51.86001 -21.58072, -51.85892 -21.5...
# 1     POLYGON ((-51.41936 -20.68108, -51.41942 -20.6...
# 2     POLYGON ((-51.48515 -21.42765, -51.48500 -21.4...
# 3     POLYGON ((-51.57097 -22.39887, -51.57099 -22.3...
# 4     POLYGON ((-52.44569 -22.60828, -52.44569 -22.6...
# ...                                                 ...
# 5567  POLYGON ((-62.12258 -10.89939, -62.12418 -10.9...
# 5568  POLYGON ((-61.95442 -9.94968, -61.95552 -9.950...
# 5569  POLYGON ((-62.15601 -11.02598, -62.15500 -11.0...
# 5570  POLYGON ((-61.57464 -9.71779, -61.58190 -9.711...
# 5571  POLYGON ((-61.97267 -10.06753, -61.97104 -10.0...
#
# [3557 rows x 9 columns]

# %%
# Save to file
gdf_2015.to_file(out_file.format(2015))

# %%
del gdf_2015

# %% [markdown]
# ## Year 2016

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2016 = readSHP(2016, in_dir)
gdf_2016.head(2)
# Out:
#               NM_MUNICIP CD_GEOCMU  \
# 0  ALTA FLORESTA D'OESTE   1100015
# 1              ARIQUEMES   1100023
#
#                                             geometry
# 0  POLYGON ((-62.19465 -11.82746, -62.19332 -11.8...
# 1  POLYGON ((-62.53648 -9.73222, -62.52765 -9.736...

# %%
# Select relevant columns
gdf_2016 = gdf_2016[['CD_GEOCMU', 'NM_MUNICIP', 'geometry']]

# %%
# Rename the relevant columns
gdf_2016 = gdf_2016.rename(columns = {'CD_GEOCMU':'m_code', 'NM_MUNICIP':'m_name'})

# %%
# Add state codes, selecting only the relevant ones
gdf_2016 = addStateCodes(gdf_2016, select = True)
# Out:
# C:\Users\scat8298\.conda\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2016 = aggregate_municipalities(gdf_2016)

# %%
# Calculate area of each municipality
gdf_2016 = calculate_area(gdf_2016)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2016 = get_latlon(gdf_2016)

# %%
# Correct municipality code
gdf_2016 = correct_m_code(gdf_2016)

# %%
# Adding year column
gdf_2016['year'] = 2016

# %%
# Ordering the columns
gdf_2016 = order_columns(gdf_2016)

# %%
# Checking the GeoDataFrame again
gdf_2016
# Out:
#       year state  s_code  m_code                 m_name     area_km2  \
# 0     2016    RO      11  110001  ALTA FLORESTA D'OESTE  7137.806306
# 1     2016    RO      11  110002              ARIQUEMES  4479.446407
# 2     2016    RO      11  110003                 CABIXI  1322.751023
# 3     2016    RO      11  110004                 CACOAL  3822.982349
# 4     2016    RO      11  110005             CEREJEIRAS  2804.665258
# ...    ...   ...     ...     ...                    ...          ...
# 5567  2016    GO      52  522200            VIANÃ“POLIS   958.424274
# 5568  2016    GO      52  522205        VICENTINÃ“POLIS   739.003152
# 5569  2016    GO      52  522220               VILA BOA  1067.467473
# 5570  2016    GO      52  522230          VILA PROPÃCIO  2189.954329
# 5571  2016    DF      53  530010               BRASÃLIA  5811.608521
#
#           latitude     longitude  \
# 0     8.606916e+06  8.606916e+06
# 1     8.886192e+06  8.886192e+06
# 2     8.500043e+06  8.500043e+06
# 3     8.740186e+06  8.740186e+06
# 4     8.528364e+06  8.528364e+06
# ...            ...           ...
# 5567  8.132084e+06  8.132084e+06
# 5568  8.034702e+06  8.034702e+06
# 5569  8.330040e+06  8.330040e+06
# 5570  8.304597e+06  8.304597e+06
# 5571  8.244839e+06  8.244839e+06
#
#                                                geometry
# 0     POLYGON ((-62.19465 -11.82746, -62.19332 -11.8...
# 1     POLYGON ((-62.53648 -9.73222, -62.52765 -9.736...
# 2     POLYGON ((-60.37075 -13.36363, -60.37134 -13.3...
# 3     POLYGON ((-61.00080 -11.29737, -61.00103 -11.3...
# 4     POLYGON ((-61.49976 -13.00525, -61.49809 -13.0...
# ...                                                 ...
# 5567  POLYGON ((-48.38114 -16.63141, -48.38058 -16.6...
# 5568  POLYGON ((-49.84456 -17.58262, -49.84357 -17.5...
# 5569  POLYGON ((-47.11416 -14.67412, -47.11289 -14.6...
# 5570  POLYGON ((-48.75586 -14.86267, -48.75519 -14.8...
# 5571  POLYGON ((-48.20054 -15.50026, -48.14051 -15.5...
#
# [3557 rows x 9 columns]

# %%
# Save to file
gdf_2016.to_file(out_file.format(2016))

# %%
del gdf_2016

# %% [markdown]
# ## Year 2017

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2017 = readSHP(2017, in_dir)
gdf_2017.head(2)
# Out:
#             NM_MUNICIP CD_GEOCMU  \
# 0      ABADIA DE GOIÃS   5200050
# 1  ABADIA DOS DOURADOS   3100104
#
#                                             geometry
# 0  POLYGON ((-49.44440 -16.71747, -49.44435 -16.7...
# 1  POLYGON ((-47.43840 -18.16570, -47.43588 -18.1...

# %%
# Select relevant columns
gdf_2017 = gdf_2017[['CD_GEOCMU', 'NM_MUNICIP', 'geometry']]

# %%
# Rename the relevant columns
gdf_2017 = gdf_2017.rename(columns = {'CD_GEOCMU':'m_code', 'NM_MUNICIP':'m_name'})

# %%
# Add state codes, selecting only the relevant ones
gdf_2017 = addStateCodes(gdf_2017, select = True)
# Out:
# C:\Users\scat8298\.conda\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2017 = aggregate_municipalities(gdf_2017)

# %%
# Calculate area of each municipality
gdf_2017 = calculate_area(gdf_2017)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2017 = get_latlon(gdf_2017)

# %%
# Correct municipality code
gdf_2017 = correct_m_code(gdf_2017)

# %%
# Adding year column
gdf_2017['year'] = 2017

# %%
# Ordering the columns
gdf_2017 = order_columns(gdf_2017)

# %%
# Checking the GeoDataFrame again
gdf_2017
# Out:
#       year state  s_code  m_code               m_name     area_km2  \
# 0     2017    GO      52  520005      ABADIA DE GOIÃS   147.683412
# 1     2017    MG      31  310010  ABADIA DOS DOURADOS   886.267593
# 2     2017    GO      52  520010           ABADIÃ‚NIA  1049.257426
# 3     2017    MG      31  310020              ABAETÃ‰  1835.632746
# 4     2017    PA      15  150010           ABAETETUBA  1616.861220
# ...    ...   ...     ...     ...                  ...          ...
# 5559  2017    PR      41  412880              XAMBRÃŠ   359.720270
# 5566  2017    PA      15  150840             XINGUARA  3790.279503
# 5567  2017    BA      29  293360          XIQUE-XIQUE  5174.110547
# 5569  2017    SP      35  355715             ZACARIAS   319.718973
# 5570  2017    MA      21  211400             ZÃ‰ DOCA  2161.521098
#
#           latitude     longitude  \
# 0     8.137880e+06  8.137880e+06
# 1     7.957506e+06  7.957506e+06
# 2     8.202408e+06  8.202408e+06
# 3     7.864522e+06  7.864522e+06
# 4     9.807907e+06  9.807907e+06
# ...            ...           ...
# 5559  7.373919e+06  7.373919e+06
# 5566  9.232828e+06  9.232828e+06
# 5567  8.762483e+06  8.762483e+06
# 5569  7.657934e+06  7.657934e+06
# 5570  9.635924e+06  9.635924e+06
#
#                                                geometry
# 0     POLYGON ((-49.44440 -16.71747, -49.44435 -16.7...
# 1     POLYGON ((-47.43840 -18.16570, -47.43588 -18.1...
# 2     POLYGON ((-48.84178 -16.00488, -48.79639 -16.0...
# 3     POLYGON ((-45.16777 -18.89073, -45.16719 -18.8...
# 4     POLYGON ((-48.83139 -1.56352, -48.82910 -1.571...
# ...                                                 ...
# 5559  POLYGON ((-53.63219 -23.65218, -53.63069 -23.6...
# 5566  POLYGON ((-49.27592 -6.62299, -49.22760 -6.686...
# 5567  POLYGON ((-42.38095 -10.24423, -42.37974 -10.2...
# 5569  POLYGON ((-49.99275 -21.03884, -49.99214 -21.0...
# 5570  POLYGON ((-45.92061 -3.02780, -45.91877 -3.028...
#
# [3557 rows x 9 columns]

# %%
# Save to file
gdf_2017.to_file(out_file.format(2017))

# %%
del gdf_2017

# %% [markdown]
# ## Year 2018

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2018 = readSHP(2018, in_dir)
gdf_2018.head(2)
# Out:
#                 NM_MUNICIP CD_GEOCMU  \
# 0       CACHOEIRA DO PIRIÃ   1501956
# 1  SÃƒO JOSÃ‰ DOS BASÃLIOS   2111250
#
#                                             geometry
# 0  POLYGON ((-46.31955 -1.75518, -46.31990 -1.755...
# 1  POLYGON ((-44.63409 -5.03498, -44.63407 -5.034...

# %%
# Select relevant columns
gdf_2018 = gdf_2018[['CD_GEOCMU', 'NM_MUNICIP', 'geometry']]

# %%
# Rename the relevant columns
gdf_2018 = gdf_2018.rename(columns = {'CD_GEOCMU':'m_code', 'NM_MUNICIP':'m_name'})

# %%
# Add state codes, selecting only the relevant ones
gdf_2018 = addStateCodes(gdf_2018, select = True)
# Out:
# C:\Users\scat8298\.conda\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2018 = aggregate_municipalities(gdf_2018)

# %%
# Calculate area of each municipality
gdf_2018 = calculate_area(gdf_2018)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2018 = get_latlon(gdf_2018)

# %%
# Correct municipality code
gdf_2018 = correct_m_code(gdf_2018)

# %%
# Adding year column
gdf_2018['year'] = 2018

# %%
# Ordering the columns
gdf_2018 = order_columns(gdf_2018)

# %%
# Checking the GeoDataFrame again
gdf_2018
# Out:
#       year state  s_code  m_code                   m_name     area_km2  \
# 0     2018    PA      15  150195       CACHOEIRA DO PIRIÃ  2440.761083
# 1     2018    MA      21  211125  SÃƒO JOSÃ‰ DOS BASÃLIOS   358.013235
# 2     2018    GO      52  520145    APARECIDA DO RIO DOCE   602.757318
# 3     2018    GO      52  520235              ARENÃ“POLIS  1075.480424
# 4     2018    PA      15  150285                    CURUÃ  1431.360952
# ...    ...   ...     ...     ...                      ...          ...
# 5564  2018    BA      29  290430                 BREJÃ•ES   533.660284
# 5565  2018    MG      31  314430                  NANUQUE  1556.614850
# 5566  2018    BA      29  290180      ANTÃ”NIO GONÃ‡ALVES   354.794917
# 5567  2018    SP      35  353550      PARAGUAÃ‡U PAULISTA  1002.984784
# 5568  2018    GO      52  520020               ÃGUA LIMPA   454.559457
#
#           latitude     longitude  \
# 0     9.778181e+06  9.778181e+06
# 1     9.435135e+06  9.435135e+06
# 2     7.982857e+06  7.982857e+06
# 3     8.189717e+06  8.189717e+06
# 4     9.795872e+06  9.795872e+06
# ...            ...           ...
# 5564  8.511097e+06  8.511097e+06
# 5565  7.981959e+06  7.981959e+06
# 5566  8.794942e+06  8.794942e+06
# 5567  7.511458e+06  7.511458e+06
# 5568  7.992614e+06  7.992614e+06
#
#                                                geometry
# 0     POLYGON ((-46.31955 -1.75518, -46.31990 -1.755...
# 1     POLYGON ((-44.63409 -5.03498, -44.63407 -5.034...
# 2     POLYGON ((-51.14230 -18.29672, -51.14236 -18.2...
# 3     POLYGON ((-51.69953 -16.23270, -51.69957 -16.2...
# 4     POLYGON ((-55.17193 -1.83331, -55.16647 -1.731...
# ...                                                 ...
# 5564  POLYGON ((-39.96092 -13.06972, -39.96092 -13.0...
# 5565  POLYGON ((-40.49485 -17.77412, -40.49531 -17.7...
# 5566  POLYGON ((-40.21792 -10.55208, -40.21585 -10.5...
# 5567  POLYGON ((-50.69420 -22.39885, -50.69410 -22.3...
# 5568  POLYGON ((-48.86197 -17.98972, -48.86111 -17.9...
#
# [3557 rows x 9 columns]

# %%
# Save to file
gdf_2018.to_file(out_file.format(2018))

# %%
del gdf_2018

# %% [markdown]
# ## Year 2019

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2019 = readSHP(2019, in_dir)
gdf_2019.head(2)
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.025
# 1  1100023              Ariquemes       RO  4426.571
#
#                                             geometry
# 0  POLYGON ((-62.22630 -11.89037, -62.20670 -11.8...
# 1  POLYGON ((-63.58751 -9.84984, -63.58715 -9.849...

# %%
# Select relevant columns
gdf_2019 = gdf_2019[['CD_MUN', 'NM_MUN', 'AREA_KM2','geometry']]

# %%
# Rename the relevant columns
gdf_2019 = gdf_2019.rename(columns = {'CD_MUN':'m_code', 'NM_MUN':'m_name', 'AREA_KM2':'area_km2'})

# %%
# Add state codes, selecting only the relevant ones
gdf_2019 = addStateCodes(gdf_2019, select = True)
# Out:
# C:\Users\scat8298\.conda\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2019 = aggregate_municipalities(gdf_2019)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2019 = get_latlon(gdf_2019)

# %%
# Correct municipality code
gdf_2019 = correct_m_code(gdf_2019)

# %%
# Adding year column
gdf_2019['year'] = 2019

# %%
# Ordering the columns
gdf_2019 = order_columns(gdf_2019)

# %%
# Checking the GeoDataFrame again
gdf_2019
# Out:
#       year state  s_code  m_code                 m_name  area_km2  \
# 0     2019    RO      11  110001  Alta Floresta D'Oeste  7067.025
# 1     2019    RO      11  110002              Ariquemes  4426.571
# 2     2019    RO      11  110003                 Cabixi  1314.352
# 3     2019    RO      11  110004                 Cacoal  3792.892
# 4     2019    RO      11  110005             Cerejeiras  2783.300
# ...    ...   ...     ...     ...                    ...       ...
# 5567  2019    GO      52  522200            VianÃ³polis   954.284
# 5568  2019    GO      52  522205        VicentinÃ³polis   737.255
# 5569  2019    GO      52  522220               Vila Boa  1060.172
# 5570  2019    GO      52  522230         Vila PropÃ­cio  2181.583
# 5571  2019    DF      53  530010              BrasÃ­lia  5760.783
#
#           latitude     longitude  \
# 0     8.606916e+06  8.606916e+06
# 1     8.886192e+06  8.886192e+06
# 2     8.500043e+06  8.500043e+06
# 3     8.740186e+06  8.740186e+06
# 4     8.528364e+06  8.528364e+06
# ...            ...           ...
# 5567  8.132084e+06  8.132084e+06
# 5568  8.034702e+06  8.034702e+06
# 5569  8.330040e+06  8.330040e+06
# 5570  8.304597e+06  8.304597e+06
# 5571  8.244784e+06  8.244784e+06
#
#                                                geometry
# 0     POLYGON ((-62.22630 -11.89037, -62.20670 -11.8...
# 1     POLYGON ((-63.58751 -9.84984, -63.58715 -9.849...
# 2     POLYGON ((-60.71834 -13.39058, -60.70904 -13.3...
# 3     POLYGON ((-61.50114 -11.30119, -61.50104 -11.2...
# 4     POLYGON ((-61.51346 -13.28575, -61.51534 -13.2...
# ...                                                 ...
# 5567  POLYGON ((-48.53842 -16.75003, -48.54051 -16.7...
# 5568  POLYGON ((-49.90713 -17.61460, -49.90588 -17.6...
# 5569  POLYGON ((-47.07742 -15.06330, -47.07747 -15.0...
# 5570  POLYGON ((-48.91463 -15.20939, -48.91462 -15.2...
# 5571  POLYGON ((-47.81455 -16.04995, -47.81478 -16.0...
#
# [3557 rows x 9 columns]

# %%
# Save to file
gdf_2019.to_file(out_file.format(2019))

# %%
del gdf_2019

# %% [markdown]
# ## Year 2020

# %%
# Get GeoDataFrame with all the states' municipalities
gdf_2020 = readSHP(2020, in_dir)
gdf_2020.head(2)
# Out:
#     CD_MUN                 NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1100015  Alta Floresta D'Oeste       RO  7067.127
# 1  1100023              Ariquemes       RO  4426.571
#
#                                             geometry
# 0  POLYGON ((-62.19465 -11.82746, -62.19332 -11.8...
# 1  POLYGON ((-62.53648 -9.73222, -62.52765 -9.736...

# %%
# Select relevant columns
gdf_2020 = gdf_2020[['CD_MUN', 'NM_MUN', 'AREA_KM2','geometry']]

# %%
# Rename the relevant columns
gdf_2020 = gdf_2020.rename(columns = {'CD_MUN':'m_code', 'NM_MUN':'m_name', 'AREA_KM2':'area_km2'})

# %%
# Add state codes, selecting only the relevant ones
gdf_2020 = addStateCodes(gdf_2020, select = True)
# Out:
# C:\Users\scat8298\.conda\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
# Before doing anything else, there might be municipalities that appear more than once. We aggregate their geometries into a 
# single row.
gdf_2020 = aggregate_municipalities(gdf_2020)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_2020 = get_latlon(gdf_2020)

# %%
# Correct municipality code
gdf_2020 = correct_m_code(gdf_2020)

# %%
# Adding year column
gdf_2020['year'] = 2020

# %%
# Ordering the columns
gdf_2020 = order_columns(gdf_2020)

# %%
# Checking the GeoDataFrame again
gdf_2020
# Out:
#       year state  s_code  m_code                 m_name  area_km2  \
# 0     2020    RO      11  110001  Alta Floresta D'Oeste  7067.127
# 1     2020    RO      11  110002              Ariquemes  4426.571
# 2     2020    RO      11  110003                 Cabixi  1314.352
# 3     2020    RO      11  110004                 Cacoal  3793.000
# 4     2020    RO      11  110005             Cerejeiras  2783.300
# ...    ...   ...     ...     ...                    ...       ...
# 5565  2020    GO      52  522200            VianÃ³polis   954.284
# 5566  2020    GO      52  522205        VicentinÃ³polis   737.255
# 5567  2020    GO      52  522220               Vila Boa  1060.172
# 5568  2020    GO      52  522230         Vila PropÃ­cio  2181.583
# 5569  2020    DF      53  530010              BrasÃ­lia  5760.784
#
#           latitude     longitude  \
# 0     8.606922e+06  8.606922e+06
# 1     8.886192e+06  8.886192e+06
# 2     8.500043e+06  8.500043e+06
# 3     8.740187e+06  8.740187e+06
# 4     8.528364e+06  8.528364e+06
# ...            ...           ...
# 5565  8.132084e+06  8.132084e+06
# 5566  8.034702e+06  8.034702e+06
# 5567  8.330040e+06  8.330040e+06
# 5568  8.304597e+06  8.304597e+06
# 5569  8.244784e+06  8.244784e+06
#
#                                                geometry
# 0     POLYGON ((-62.19465 -11.82746, -62.19332 -11.8...
# 1     POLYGON ((-62.53648 -9.73222, -62.52765 -9.736...
# 2     POLYGON ((-60.37119 -13.36655, -60.37134 -13.3...
# 3     POLYGON ((-61.00080 -11.29737, -61.00103 -11.3...
# 4     POLYGON ((-61.49976 -13.00525, -61.49809 -13.0...
# ...                                                 ...
# 5565  POLYGON ((-48.38114 -16.63141, -48.38058 -16.6...
# 5566  POLYGON ((-49.84456 -17.58262, -49.84357 -17.5...
# 5567  POLYGON ((-47.11416 -14.67412, -47.11289 -14.6...
# 5568  POLYGON ((-48.75586 -14.86267, -48.75519 -14.8...
# 5569  POLYGON ((-47.41734 -15.54655, -47.41720 -15.5...
#
# [3557 rows x 9 columns]

# %%
# Save to file
gdf_2020.to_file(out_file.format(2020))

# %%
del gdf_2020

# %% [markdown]
# # Year 1991

# %%
# Read SHP file
gdf_1991 = gpd.read_file('../../data/raw/BRA_population/05_malha_municipal_1991/05-malha municipal 1991.shp')
gdf_1991.head(2)
# Out:
#    BR91POLY_I NOMEMUNICP                                           geometry
# 0     1400407  NORMANDIA  POLYGON ((-713352.505 556340.624, -713339.209 ...
# 1     1400100  BOA VISTA  POLYGON ((-713352.505 556340.624, -714720.572 ...

# %%
# Rename columns
gdf_1991 = gdf_1991.rename(columns = {'BR91POLY_I':'m_code', 'NOMEMUNICP':'m_name'})

# %%
# Correct municipalities' code
gdf_1991 = correct_m_code(gdf_1991)

# %%
# Checking if duplicated and merging
gdf_1991 = aggregate_municipalities(gdf_1991)
# Out:
# There were duplicated municiaplities.

# %%
# Adding the states information
gdf_1991 = addStateCodes(gdf_1991, select = True)
# Out:
# C:\Users\scat8298\Miniconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Calculate area of each municipality
gdf_1991 = calculate_area(gdf_1991)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_1991 = get_latlon(gdf_1991)

# %%
# Adding year column
gdf_1991['year'] = 1991

# %%
# Ordering the columns
gdf_1991 = order_columns(gdf_1991)

# %%
# Checking the GeoDataFrame again
gdf_1991
# Out:
#       year state  s_code  m_code                 m_name      area_km2  \
# 1     1991    RO      11  110001  ALTA FLORESTA D'OESTE   8643.900381
# 2     1991    RO      11  110002              ARIQUEMES  14520.381508
# 3     1991    RO      11  110003                 CABIXI   1987.588535
# 4     1991    RO      11  110004                 CACOAL   4699.655848
# 5     1991    RO      11  110005             CEREJEIRAS  10798.148551
# ...    ...   ...     ...     ...                    ...           ...
# 4487  1991    GO      52  522180                 URUTAI    632.098289
# 4488  1991    GO      52  522190                 VARJAO    518.316883
# 4489  1991    GO      52  522200             VIANOPOLIS    957.436766
# 4490  1991    GO      52  522205         VICENTINOPOLIS    738.876438
# 4491  1991    DF      53  530010               BRASILIA   5833.248016
#
#           latitude     longitude  \
# 1     8.610290e+06  8.610290e+06
# 2     8.896478e+06  8.896478e+06
# 3     8.502898e+06  8.502898e+06
# 4     8.743491e+06  8.743491e+06
# 5     8.541746e+06  8.541746e+06
# ...            ...           ...
# 4487  8.062210e+06  8.062210e+06
# 4488  8.105886e+06  8.105886e+06
# 4489  8.132213e+06  8.132213e+06
# 4490  8.034881e+06  8.034881e+06
# 4491  8.244935e+06  8.244935e+06
#
#                                                geometry
# 1     POLYGON ((-894106.624 -1321512.696, -892240.57...
# 2     POLYGON ((-955417.091 -990340.198, -954103.839...
# 3     POLYGON ((-688195.518 -1477799.099, -688365.12...
# 4     POLYGON ((-825053.588 -1225176.945, -764976.70...
# 5     POLYGON ((-797089.979 -1407434.906, -799229.49...
# ...                                                 ...
# 4487  POLYGON ((625270.725 -1920042.756, 628472.000 ...
# 4488  POLYGON ((481426.601 -1883495.983, 482427.897 ...
# 4489  POLYGON ((575558.017 -1879669.749, 575998.245 ...
# 4490  POLYGON ((432650.408 -1951835.635, 434540.366 ...
# 4491  POLYGON ((697809.430 -1724792.744, 706240.248 ...
#
# [2873 rows x 9 columns]

# %%
# Save to file
gdf_1991.to_file('../../data/shapes/municipalities_shp/municipalities_1991.shp')

# %% [markdown]
# # Year 1980

# %%
# Read SHP file
gdf_1980 = gpd.read_file('../../data/raw/BRA_population/05_malha_municipal_1980/05-malha municipal 1980.shp')
gdf_1980.head(2)
# Out:
#     codigo             nome                                           geometry
# 0  3540408         Populina  POLYGON ((354410.500 -2200448.000, 355431.906 ...
# 1  3518008  Guarani d'Oeste  POLYGON ((371553.688 -2192405.250, 375432.438 ...

# %%
# Rename columns
gdf_1980 = gdf_1980.rename(columns = {'codigo':'m_code', 'nome':'m_name'})

# %%
# Correct municipalities' code
gdf_1980 = correct_m_code(gdf_1980)

# %%
# Checking if duplicated and merging
gdf_1980 = aggregate_municipalities(gdf_1980)

# %%
# Adding the states information
gdf_1980 = addStateCodes(gdf_1980, select = True)
# Out:
# C:\Users\scat8298\Miniconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Calculate area of each municipality
gdf_1980 = calculate_area(gdf_1980)

# %%
# Calculating the latitude and longitude of the centroid of each municipality
gdf_1980 = get_latlon(gdf_1980)

# %%
# Adding year column
gdf_1980['year'] = 1980

# %%
# Ordering the columns
gdf_1980 = order_columns(gdf_1980)

# %%
# Checking the GeoDataFrame again
gdf_1980
# Out:
#       year state  s_code  m_code           m_name      area_km2      latitude  \
# 0     1980    SP      35  354040         Populina    313.402395  7.794270e+06
# 1     1980    SP      35  351800  Guarani d'Oeste    374.567430  7.788618e+06
# 2     1980    SP      35  353590        Paranapuã    291.152283  7.783292e+06
# 3     1980    SP      35  352070        Indiaporã    278.596543  7.789151e+06
# 4     1980    SP      35  353000     Mira Estrela    216.302488  7.788427e+06
# ...    ...   ...     ...     ...              ...           ...           ...
# 3980  1980    MA      21  210540  Itapecuru Mirim   1557.101055  9.614705e+06
# 3985  1980    BA      29  291840         Juazeiro   7919.669851  8.913289e+06
# 3986  1980    PR      41  411580       Medianeira   1122.211604  7.200564e+06
# 3988  1980    MT      51  510170  Barra do Bugres  10512.049028  8.338239e+06
# 3989  1980    GO      52  520240          Arraias   5761.017404  8.574651e+06
#
#          longitude                                           geometry
# 0     7.794270e+06  POLYGON ((354410.500 -2200448.000, 355431.906 ...
# 1     7.788618e+06  POLYGON ((371553.687 -2192405.250, 375432.438 ...
# 2     7.783292e+06  POLYGON ((354410.500 -2200448.000, 355143.750 ...
# 3     7.789151e+06  POLYGON ((383700.063 -2201954.250, 386854.125 ...
# 4     7.788427e+06  POLYGON ((400752.187 -2202889.250, 402301.625 ...
# ...            ...                                                ...
# 3980  9.614705e+06  POLYGON ((1095155.250 -369277.531, 1107633.500...
# 3985  8.913289e+06  POLYGON ((1515874.375 -1030961.750, 1519898.00...
# 3986  7.200564e+06  POLYGON ((-4955.584 -2781556.500, -3314.363 -2...
# 3988  8.338239e+06  POLYGON ((-338802.344 -1614383.750, -337243.15...
# 3989  8.574651e+06  POLYGON ((765496.092 -1378421.103, 767044.737 ...
#
# [2587 rows x 9 columns]

# %% [markdown]
# After looking at the formatted file, I have discovered that Tocantins was not correctly coded. This is because Tocantins was created only in 1988 as a division of Goias. Hence, in the SHP of 1980, Tocantins is coded with the number 52, which is the coide of Goias. I need to correct for this.
#
# Since I know that the only municipalities with missing population data in this SHP file after merging with the data file are those in Tocantins.

# %%
# Reading the data
data = pd.read_csv('../../data/raw/BRA_population/municipality_population_1981-2012.csv')

# Selecting relevant columns
data = data[['m_code', '1985']]

# %%
# Merging the data
gdf_1980 = gdf_1980.merge(data, on= 'm_code', how = 'left')

# %%
sum(gdf_1980['1985'].isna())
# Out:
# 52

# %%
# All these rows, their code should be changed

# %%
gdf_1980.head()
# Out:
#    year state  s_code  m_code           m_name    area_km2      latitude  \
# 0  1980    SP      35  354040         Populina  313.402395  7.794270e+06
# 1  1980    SP      35  351800  Guarani d'Oeste  374.567430  7.788618e+06
# 2  1980    SP      35  353590        Paranapuã  291.152283  7.783292e+06
# 3  1980    SP      35  352070        Indiaporã  278.596543  7.789151e+06
# 4  1980    SP      35  353000     Mira Estrela  216.302488  7.788427e+06
#
#       longitude                                           geometry    1985
# 0  7.794270e+06  POLYGON ((354410.500 -2200448.000, 355431.906 ...  4695.0
# 1  7.788618e+06  POLYGON ((371553.687 -2192405.250, 375432.438 ...  7604.0
# 2  7.783292e+06  POLYGON ((354410.500 -2200448.000, 355143.750 ...  5787.0
# 3  7.789151e+06  POLYGON ((383700.063 -2201954.250, 386854.125 ...  5742.0
# 4  7.788427e+06  POLYGON ((400752.187 -2202889.250, 402301.625 ...  2544.0

# %%
gdf_1980.loc[test['1985'].isna(), 's_code'] = 17
gdf_1980.loc[test['1985'].isna(), 'state'] = 'TO'
gdf_1980.loc[test['1985'].isna(), 'm_code'] = [int('17' + str(i)[2:]) for i in gdf_1980[gdf_1980['1985'].isna()]['m_code'].tolist()]

# %%
gdf_1980 = order_columns(gdf_1980)

# %%
# Checking it worked
gdf_1980[gdf_1980['state'] == 'TO'].head()
# Out:
#       year state  s_code  m_code                      m_name     area_km2  \
# 2020  1980    TO      17  172030  São Sebastião do Tocantins  1574.774265
# 2021  1980    TO      17  170220                  Araguatins  3052.074035
# 2022  1980    TO      17  171070                  Itaguatins  1823.240061
# 2023  1980    TO      17  172080         Sítio Novo de Goiás   195.688470
# 2024  1980    TO      17  170290              Axixá de Goiás   104.890063
#
#           latitude     longitude  \
# 2020  9.405265e+06  9.405265e+06
# 2021  9.369824e+06  9.369824e+06
# 2022  9.366943e+06  9.366943e+06
# 2023  9.372621e+06  9.372621e+06
# 2024  9.373473e+06  9.373473e+06
#
#                                                geometry
# 2020  POLYGON ((652714.801 -585263.348, 656366.160 -...
# 2021  POLYGON ((590266.664 -591491.596, 591776.101 -...
# 2022  POLYGON ((690711.821 -598153.519, 693369.244 -...
# 2023  POLYGON ((682654.707 -622712.504, 701368.173 -...
# 2024  POLYGON ((682871.007 -624097.990, 682654.707 -...

# %%
# Save to file
gdf_1980.to_file('../../data/shapes/municipalities_shp/municipalities_1980.shp')
